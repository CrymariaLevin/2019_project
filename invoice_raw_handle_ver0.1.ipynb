# %%
import pymysql
import pandas

sql = "SELECT * from account_xsz_190514 where 日期 !=''" 
         #"FROM dic_company m JOIN dic_company_detail n ON m.id = n.company_id WHERE m.com_group = 1"


connection = pymysql.connect(host = '47.92.25.70',user = 'root',password = 'Wfn031641',db = 'cxd_data',charset = 'utf8')

df = pandas.read_sql(sql,connection)
#df[df['日期'].notnull()]
df.head()
# Out:
#         id          日期 凭证字号       摘要      科目代码                科目名称   币别   汇率  \
# 0  4067147  2019-01-31  通-1  摊销1月会员费  18010106  长期待摊费用 - 开办费 - 管理费  RMB  0.0
# 1  4067151  2019-01-31  通-2   结转折旧费用  18010105  长期待摊费用 - 开办费 - 折旧费  RMB  0.0
# 2  4067153  2019-02-28  通-1  摊销2月会员费  18010106  长期待摊费用 - 开办费 - 管理费  RMB  0.0
# 3  4067157  2019-03-31  通-1  摊销3月会员费  18010106  长期待摊费用 - 开办费 - 管理费  RMB  0.0
# 4  4067161  2019-03-31  通-2    支付服务费  18010101  长期待摊费用 - 开办费 - 办公费  RMB  0.0
#
#       原币金额     借方金额  贷方金额 数量 单价            com            add_time
# 0  3537.74  3537.74   0.0        大连国通鸿儒新能源有限公司 2019-05-14 15:05:07
# 1  2632.08  2632.08   0.0        大连国通鸿儒新能源有限公司 2019-05-14 15:05:07
# 2  3537.74  3537.74   0.0        大连国通鸿儒新能源有限公司 2019-05-14 15:05:07
# 3  3537.74  3537.74   0.0        大连国通鸿儒新能源有限公司 2019-05-14 15:05:07
# 4   886.79   886.79   0.0        大连国通鸿儒新能源有限公司 2019-05-14 15:05:07

# %%
list_need = []
for index in df.index:
    name = df.loc[index, '科目名称']
    #scope = df.loc[index, '经营范围']
    if '汽油' in name or '柴油' in name:
    #if '92' in name and '油' in name:
        list_need.append(index)
df_new = df.loc[list_need]
df_new.head()
# Out:
#          id          日期 凭证字号  摘要    科目代码                         科目名称   币别  \
# 51  4067294  2019/01/31  记-1  购货  124321          库存商品 - 车用柴油（VI)-10#  RMB
# 95  4067445  2019/03/31  记-1  购货  124321          库存商品 - 车用柴油（VI)-10#  RMB
# 96  4067448  2019/03/31  记-2  购货  124322            库存商品 - 0号车用柴油（VI）  RMB
# 97  4067451  2019/03/31  记-3  购货  124323  库存商品 - 车用柴油（VI）  0号车用柴油（VI）  RMB
# 98  4067454  2019/03/31  记-4  购货  124320           库存商品 - 车用柴油（V)-10#  RMB
#
#      汇率        原币金额        借方金额  贷方金额       数量        单价           com  \
# 51  0.0   257117.24   257117.24   0.0    50.40  5,101.53  大连永润石油化工有限公司
# 95  0.0   167018.58   167018.58   0.0    35.06  4,763.79  大连永润石油化工有限公司
# 96  0.0    26266.81    26266.81   0.0     5.49  4,784.48  大连永润石油化工有限公司
# 97  0.0  1203561.74  1203561.74   0.0  248.422  4,844.83  大连永润石油化工有限公司
# 98  0.0   217786.69   217786.69   0.0   41.613  5,233.62  大连永润石油化工有限公司
#
#               add_time
# 51 2019-05-14 15:05:08
# 95 2019-05-14 15:05:08
# ...

# %%
df2 = df_new[df_new['摘要'].str.contains('购')]
#df2.to_excel('E:/0517.xls', index=False)
df2
# Out:
#             id          日期  凭证字号                  摘要     科目代码  \
# 51     4067294  2019/01/31   记-1                  购货   124321
# 95     4067445  2019/03/31   记-1                  购货   124321
# 96     4067448  2019/03/31   记-2                  购货   124322
# 97     4067451  2019/03/31   记-3                  购货   124323
# 98     4067454  2019/03/31   记-4                  购货   124320
# 99     4067457  2019/03/31   记-5                  购货   124320
# 100    4067460  2019/03/31   记-6                  购货   124322
# 101    4067463  2019/03/31   记-7                  购货   124311
# 117    4067517  2019/03/31  记-23                  购货   124321
# 128    4067549  2019/01/31   记-1                  购货   124305
# 129    4067552  2019/01/31   记-2                  购货   124308
# 130    4067555  2019/01/31   记-3                  购货   124308
# 145    4067633  2019/01/31  记-18                  购货   124308
# 151    4067654  2019/02/28   记-1                  购货   124308
# ...

# %%
df2.to_csv('E:/0520.csv', index=False)

# %%
import re

info_list_all = []
for index in df2.index:
    info = df2.loc[index, '摘要']
    info_list = re.split(r'[-（：\s]\s*', info)
    info_list_all.append(info_list)
info_list_all
# Out:
# [['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购京标VI柴油', '', '10#'],
#  ['购京标VI柴油', '', '20#'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
#  ['购货'],
# ...
